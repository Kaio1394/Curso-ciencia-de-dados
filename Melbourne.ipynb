# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaio1394/Curso-ciencia-de-dados/blob/master/Melbourne.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import regex as re

# %%
data = pd.read_csv('MELBOURNE_HOUSE_PRICES_LESS.csv')

# %%
# Colunas do dataframe
data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Postcode', 'Regionname', 'Propertycount', 'Distance',
#        'CouncilArea'],
#       dtype='object')

# %%
# Exibição das 5 primeiras linhas
data.head()
# Out:
#          Suburb           Address  Rooms Type      Price Method   SellerG  \
# 0    Abbotsford     49 Lithgow St      3    h  1490000.0      S    Jellis
# 1    Abbotsford     59A Turner St      3    h  1220000.0      S  Marshall
# 2    Abbotsford     119B Yarra St      3    h  1420000.0      S    Nelson
# 3    Aberfeldie        68 Vida St      3    h  1515000.0      S     Barry
# 4  Airport West  92 Clydesdale Rd      2    h   670000.0      S    Nelson
#
#         Date  Postcode             Regionname  Propertycount  Distance  \
# 0  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 1  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 2  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 3  1/04/2017      3040   Western Metropolitan           1543       7.5
# 4  1/04/2017      3042   Western Metropolitan           3464      10.4
#
#                   CouncilArea
# 0          Yarra City Council
# 1          Yarra City Council
# ...

# %%
# Quantidade de linhas
len(data)
# Out:
# 63023

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63023 entries, 0 to 63022
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         63023 non-null  object
#  1   Address        63023 non-null  object
#  2   Rooms          63023 non-null  int64
#  3   Type           63023 non-null  object
#  4   Price          48433 non-null  float64
#  5   Method         63023 non-null  object
#  6   SellerG        63023 non-null  object
#  7   Date           63023 non-null  object
#  8   Postcode       63023 non-null  int64
#  9   Regionname     63023 non-null  object
#  10  Propertycount  63023 non-null  int64
#  11  Distance       63023 non-null  float64
#  12  CouncilArea    63023 non-null  object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 6.3+ MB

# %%
data.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price            14590
# Method               0
# SellerG              0
# Date                 0
# Postcode             0
# Regionname           0
# Propertycount        0
# Distance             0
# CouncilArea          0
# dtype: int64

# %%
# Trocando valores NaN por zero
data['Price'] = data['Price'].fillna(0)

# Preços com valores zerados
data.loc[data['Price'] == 0.0]
# Out:
#                  Suburb                Address  Rooms Type  Price Method  \
# 8             Albanvale          1 Jackson Cct      6    h    0.0     PI
# 15       Altona Meadows           57 Tatman Dr      4    h    0.0     SN
# 24            Ashburton              1 Pitt St      4    h    0.0      S
# 29              Attwood     46 Threadneedle St      4    h    0.0     SN
# 38         Balwyn North            12 Agnes Av      3    h    0.0     SP
# ...                 ...                    ...    ...  ...    ...    ...
# 63001      Wyndham Vale          15 Yaltara Dr      3    h    0.0      S
# 63008        Yarraville  4/247 Williamstown Rd      3    t    0.0      S
# 63010           Burwood           29 Summit Rd      4    h    0.0     PN
# 63021        Thomastown         3/1 Travers St      3    u    0.0     PI
# 63022  Williams Landing            1 Diadem Wy      4    h    0.0     SP
#
#              SellerG        Date  Postcode             Regionname  \
# ...

# %%
# Casa com valor de preço maior
data.sort_values('Price', ascending=False)
# Out:
#              Suburb           Address  Rooms Type      Price Method  \
# 23841    Canterbury    49 Mangarra Rd      5    h  8000000.0     VB
# 1593         Toorak        12 Hill St      5    h  6700000.0     VB
# 7825       Armadale     507 Orrong Rd     10    h  6600000.0      S
# 17683       Malvern    6 Moorakyne Av      5    h  6600000.0      S
# 24587           Kew       15 Barry St      6    h  6500000.0      S
# ...             ...               ...    ...  ...        ...    ...
# 27196      St Kilda   3/11 Herbert St      2    u        NaN      S
# 27214  Surrey Hills  61A Broughton Rd      4    t        NaN     VB
# 27225   Templestowe      2/2 Wyena Wy      2    u        NaN      S
# 27232     Thornbury  72 Ballantyne St      3    h        NaN      S
# 27241        Toorak    699 Malvern Rd      4    h        NaN      S
#
#          SellerG        Date  Postcode             Regionname  Propertycount  \
# ...

# %%
# Filtrando dados
filter = data.loc[(data['Rooms'] == 3) & (data['Type'] == 'h') & data['Price'] <= 200000]
filter
# Out:
#              Suburb           Address  Rooms Type      Price Method  \
# 0        Abbotsford     49 Lithgow St    3.0    h  1490000.0      S
# 1        Abbotsford     59A Turner St    3.0    h  1220000.0      S
# 2        Abbotsford     119B Yarra St    3.0    h  1420000.0      S
# 3        Aberfeldie        68 Vida St    3.0    h  1515000.0      S
# 4      Airport West  92 Clydesdale Rd    2.0    h   670000.0      S
# ...             ...               ...    ...  ...        ...    ...
# 54366        Epping    53 Hayston Bvd    3.0    h   465000.0      S
# 54367        Epping       13 Orlit Ct    4.0    h   545000.0     PI
# 54368        Epping     14A Supply Dr    2.0    h   452500.0      S
# 54369      Essendon       9 Amelia Av    4.0    h  1577000.0      S
# 54370      Essendon               100    NaN  NaN        NaN    NaN
#
#          SellerG        Date  Postcode             Regionname  Propertycount  \
# ...

# %% [markdown]
# # Filtrando com regex

# %%
# Filtrando com o método contains()
# 'turner st|turner Rd' -> contains('Turner St' or 'Turner Rd')
# 'flags'=re.I -> ignora letras maísculas
data.loc[data['Address'].str.contains('turner st|turner Rd', flags=re.I)]
# Out:
#              Suburb            Address  Rooms   Type      Price   Method  \
# 1        Abbotsford      59A Turner St      3      h  1220000.0        S
# 2859   Malvern East       24 Turner St      6      h  4700000.0        S
# 4723        Highett       48 Turner Rd      2      h   832000.0        S
# 4987     Abbotsford       85 Turner St      2      h  1480000.0        S
# 7501        Highett       28 Turner Rd      3      h        0.0       PI
# 9647     Abbotsford       53 Turner St      2      h        0.0        S
# 9648     Abbotsford       99 Turner St      2      h        0.0        S
# 14012       Berwick        4 Turner St      5      h   536000.0        S
# 14745   Westmeadows       16 Turner St      3      h        0.0       SN
# 18960  Moonee Ponds     3/16 Turner St      2      u   550000.0       VB
# 19148    Abbotsford  106/119 Turner St      1      u   481000.0       SP
# 19609       Highett     2/20 Turner Rd      2      u   730000.0       SP
# ...

# %%
# '^59' -> Inicie como 59
data.loc[data['Address'].str.contains('^59') & (data['Price'] <= 1000000)]
# Out:
#             Suburb            Address  Rooms Type     Price Method  \
# 182        Croydon      59 Wicklow Av      3    h  965000.0      S
# 770    Craigieburn      59 Balyang Wy      4    h  607000.0      S
# 797         Eltham        59 Bible St      3    h  975000.0      S
# 807         Epping  59 Greenfields Dr      4    h  940000.0     SP
# 1698     Braybrook        59 South Rd      3    h  700000.0     VB
# ...            ...                ...    ...  ...       ...    ...
# 61169     Oak Park     59 Winifred St      4    h  921000.0      S
# 61190      Prahran        59 Perth St      2    h       0.0     SP
# 61832   Cheltenham        59 Nancy St      4    h  970000.0      S
# 62796   Point Cook    59 Breasley Pky      3    h  670000.0      S
# 62903      Sunbury    59 Davenport Dr      3    h  499500.0      S
#
#              SellerG        Date  Postcode             Regionname  \
# 182           Carter   1/04/2017      3136   Eastern Metropolitan
# ...

# %%
# Trocando valores da tabela
data.loc[data['SellerG'] == 'Nelson', 'SellerG'] = 'Kaio'

# %%
# Confirmando valore trocado
data.loc[data['SellerG'] == 'Kaio']
# Out:
#              Suburb             Address  Rooms Type      Price Method SellerG  \
# 2        Abbotsford       119B Yarra St      3    h  1420000.0      S    Kaio
# 4      Airport West    92 Clydesdale Rd      2    h   670000.0      S    Kaio
# 7      Airport West   1/26 Highridge Cr      3    h   715000.0     SP    Kaio
# 50        Bellfield      1/15 Toohey St      3    u   675000.0     SP    Kaio
# 94        Brunswick        53 Amelia St      2    h   740000.0     PI    Kaio
# ...             ...                 ...    ...  ...        ...    ...     ...
# 62841     Reservoir    2/61 Marchant Av      2    t   600000.0      S    Kaio
# 62843     Reservoir        19 Ramleh Rd      4    h   890000.0      S    Kaio
# 62847      Richmond        37 Cutter St      3    h  1490000.0      S    Kaio
# 62851      Richmond    81 Wellington St      2    h  1145000.0      S    Kaio
# 62901    Strathmore  3/40 Glenbervie Rd      3    u   900000.0     VB    Kaio
#
# ...

# %%
# Alterando valores de mais de uma coluna
data.loc[data['SellerG'] == 'Kaio', ['Method', 'Type']] = 'Pending', 'Teste'
data.loc[data['SellerG'] == 'Kaio']
# Out:
#              Suburb             Address  Rooms   Type      Price   Method  \
# 2        Abbotsford       119B Yarra St      3  Teste  1420000.0  Pending
# 4      Airport West    92 Clydesdale Rd      2  Teste   670000.0  Pending
# 7      Airport West   1/26 Highridge Cr      3  Teste   715000.0  Pending
# 50        Bellfield      1/15 Toohey St      3  Teste   675000.0  Pending
# 94        Brunswick        53 Amelia St      2  Teste   740000.0  Pending
# ...             ...                 ...    ...    ...        ...      ...
# 62841     Reservoir    2/61 Marchant Av      2  Teste   600000.0  Pending
# 62843     Reservoir        19 Ramleh Rd      4  Teste   890000.0  Pending
# 62847      Richmond        37 Cutter St      3  Teste  1490000.0  Pending
# 62851      Richmond    81 Wellington St      2  Teste  1145000.0  Pending
# 62901    Strathmore  3/40 Glenbervie Rd      3  Teste   900000.0  Pending
#
#       SellerG        Date  Postcode             Regionname  Propertycount  \
# ...

# %% [markdown]
# # Groupby

# %%
# Realiza o somatório de todas as colunas dos vendedores "data.groupby(['SellerG']).sum()".
# E lista os 10 que mais venderam "sort_values('Price', ascending=False).head(10)" de forma descrescente
data.groupby(['SellerG']).sum().sort_values('Price', ascending=False).head(10)
# Out:
#                Rooms         Price  Postcode  Propertycount  Distance
# SellerG
# Jellis         16948  5.301902e+09  17116422       42958979   47831.6
# Kaio           13808  4.089097e+09  14489179       35455466   34410.5
# Barry          22919  4.022899e+09  21405391       54662639  108662.2
# Marshall        9437  3.337732e+09   8949613       22270034   20141.4
# hockingstuart  12635  3.174822e+09  13571171       36291698   53918.3
# Buxton         10707  3.103258e+09  10669223       21365913   48190.6
# Ray            14961  2.953669e+09  14329293       41191735   76239.1
# Fletchers       5402  1.384292e+09   5039345       10521475   21963.2
# Biggin          4203  1.002292e+09   4783284       12904764   12250.2
# Noel            3447  9.618405e+08   3328766        6571572   14386.3
